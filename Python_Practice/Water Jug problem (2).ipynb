# %%
a=int(input("Enter initial water in Jug A "))
b=int(input("Enter initial water in Jug B "))

while((a!=2 or b!=0)):
    print("\nOperations to perform \n")
    print("0. To terminate the operation\n")
    print("1. Fill the 4 Liter jug completely \n")
    print("2. Fill the 3 Liter jug completely \n")
    print("3. Pour some part from the 4 Liter jug \n")
    print("4. Pour some part from the 3 Liter jug \n")
    print("5. Empty the 4 Liter jug \n")
    print("6. Empty the 3 Liter jug \n")
    print("7. Pour some water from the 3 Liter jug to fill the 4 Liter jug \n")
    print("8. Pour some water from the 4 Liter jug to fill the 3 Liter jug \n")
    print("9. Pour all water from 3 Liter jug to the 4 Liter jug \n")
    print("10.Pour all water from the 4 Liter jug to the 3 Liter jug \n")


    inp=int(input("\nEnter the operation number to perform "))
    if(inp==0):
        print("Operation terminated!!")
        break
    if(inp==1):
        a=4
    elif(inp==2):
        b=3
    elif(inp==3):
        temp1=int(input("How much water to pour from 4 Liter jug to 3 Liter jug"))
        if(temp1+b>3):
            print("Capacity exceeds")
        else:
            b=temp1+b
    elif(inp==4):
        temp1=int(input("How much water to pour from 3 Liter jug to 4 Liter jug"))
        if(temp1+b>4):
            print("Capacity exceeds")
        else:
            a=temp1+a
    elif(inp==5):
        a=0
    elif(inp==6):
        b=0
    elif(inp==7):
        if(4-a>b):
            a=a+b
            b=0
        else:
            b=b-(4-a)
            a=4
    elif(inp==8):
        if(3-b>a):
            b=a+b
            a=0
        else:
            a=a-(3-b)
            b=3
    elif(inp==9):
        a=a+b
        b=0
    elif(inp==10):
        b=b+a
        a=0
    print(a,b)
# Out:
# Enter initial water in Jug A 3
# Enter initial water in Jug B 2
#
# Operations to perform
#
# 0. To terminate the operation
#
# 1. Fill the 4 Liter jug completely
#
# 2. Fill the 3 Liter jug completely
#
# 3. Pour some part from the 4 Liter jug
#
# 4. Pour some part from the 3 Liter jug
#
# 5. Empty the 4 Liter jug
#
# 6. Empty the 3 Liter jug
#
# 7. Pour some water from the 3 Liter jug to fill the 4 Liter jug
#
# 8. Pour some water from the 4 Liter jug to fill the 3 Liter jug
#
# 9. Pour all water from 3 Liter jug to the 4 Liter jug
#
# 10.Pour all water from the 4 Liter jug to the 3 Liter jug
#
#
# Enter the operation number to perform 6
# 3 0
#
# Operations to perform
#
# 0. To terminate the operation
#
# 1. Fill the 4 Liter jug completely
#
# 2. Fill the 3 Liter jug completely
#
# 3. Pour some part from the 4 Liter jug
#
# 4. Pour some part from the 3 Liter jug
#
# 5. Empty the 4 Liter jug
#
# 6. Empty the 3 Liter jug
#
# 7. Pour some water from the 3 Liter jug to fill the 4 Liter jug
#
# 8. Pour some water from the 4 Liter jug to fill the 3 Liter jug
#
# 9. Pour all water from 3 Liter jug to the 4 Liter jug
#
# 10.Pour all water from the 4 Liter jug to the 3 Liter jug
#
#
# Enter the operation number to perform
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [13], in <cell line: 4>()
#      15 print("9. Pour all water from 3 Liter jug to the 4 Liter jug \n")
#      16 print("10.Pour all water from the 4 Liter jug to the 3 Liter jug \n")
# ---> 19 inp=int(input("\nEnter the operation number to perform "))
#      20 if(inp==0):
#      21     print("Operation terminated!!")
#
# ValueError: invalid literal for int() with base 10: ''

# %%
d = {1:"Fill the 4 Liter jug completely ",
    2: "Fill the 3 Liter jug completely ",
    3:"Pour some part from the 4 Liter jug",
    4 : "Pour some part from the 3 Liter jug",
    5 : "Empty the 4 Liter jug",
    6 : "Empty the 3 Liter jug",
    7 : "Pour some water from the 3 Liter jug to fill the 4 Liter jug",
    8 : "Pour some water from the 4 Liter jug to fill the 3 Liter jug",
    9 : "Pour all water from 3 Liter jug to the 4 Liter jug",
    10 : "Pour all water from the 4 Liter jug to the 3 Liter jug"}

# %%
a=int(input("Enter initial water in Jug A "))
b=int(input("Enter initial water in Jug B "))

print("Operation to be performed:")
print(d)

while((a!=2 or b!=0)):

    inp=int(input("\nEnter the operation number to perform "))
    
    if(inp==1):
        a=4
    elif(inp==2):
        b=3
    elif(inp==3):
        temp1=int(input("How much water to pour from 4 Liter jug to 3 Liter jug"))
        if(temp1+b>3):
            print("Capacity exceeds")
        else:
            b=temp1+b
    elif(inp==4):
        temp1=int(input("How much water to pour from 3 Liter jug to 4 Liter jug"))
        if(temp1+b>4):
            print("Capacity exceeds")
        else:
            a=temp1+a
    elif(inp==5):
        a=0
    elif(inp==6):
        b=0
    elif(inp==7):
        if(4-a>b):
            a=a+b
            b=0
        else:
            b=b-(4-a)
            a=4
    elif(inp==8):
        if(3-b>a):
            b=a+b
            a=0
        else:
            a=a-(3-b)
            b=3
    elif(inp==9):
        a=a+b
        b=0
    elif(inp==10):
        b=b+a
        a=0
    print(a,b)
# Out:
# Enter initial water in Jug A 4
# Enter initial water in Jug B 3
# Operation to be performed:
# {1: 'Fill the 4 Liter jug completely ', 2: 'Fill the 3 Liter jug completely ', 3: 'Pour some part from the 4 Liter jug', 4: 'Pour some part from the 3 Liter jug', 5: 'Empty the 4 Liter jug', 6: 'Empty the 3 Liter jug', 7: 'Pour some water from the 3 Liter jug to fill the 4 Liter jug', 8: 'Pour some water from the 4 Liter jug to fill the 3 Liter jug', 9: 'Pour all water from 3 Liter jug to the 4 Liter jug', 10: 'Pour all water from the 4 Liter jug to the 3 Liter jug'}
#
# Enter the operation number to perform 2
# 4 3
#
# Enter the operation number to perform 3
# How much water to pour from 4 Liter jug to 3 Liter jug4
# Capacity exceeds
# 4 3
#
# Enter the operation number to perform 4
# How much water to pour from 3 Liter jug to 4 Liter jug5
# Capacity exceeds
# 4 3
#
# Enter the operation number to perform 5
# 0 3
#
# Enter the operation number to perform 6
# 0 0
#
# Enter the operation number to perform 7
# 0 0
#
# Enter the operation number to perform 8
# 0 0
#
# Enter the operation number to perform 9
# 0 0
#
# Enter the operation number to perform 2
# 0 3
#
# Enter the operation number to perform 4
# How much water to pour from 3 Liter jug to 4 Liter jug1
# 1 3
#
# Enter the operation number to perform  4
# How much water to pour from 3 Liter jug to 4 Liter jug
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [9], in <cell line: 7>()
#      20         b=temp1+b
#      21 elif(inp==4):
# ---> 22     temp1=int(input("How much water to pour from 3 Liter jug to 4 Liter jug"))
#      23     if(temp1+b>4):
#      24         print("Capacity exceeds")
#
# ValueError: invalid literal for int() with base 10: ' '
